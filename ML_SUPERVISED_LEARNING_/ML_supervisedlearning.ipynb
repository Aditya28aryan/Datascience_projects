# 548    0
# 36     1
# 284    0
# 194    1
# 250    0
# 374    0
# 262    0
# 410    0
# 144    0
# 204    1
# 316    1
# 235    0
# 782    0
# 601    0
# 367    1
# 249    0
# 461    0
# 432    1
# 619    0
# 708    1
# 348    1
# 297    0
# 324    0
# 746    0
# 350    0
# 764    0
# 458    1
# 857    1
# 320    0
# 313    0
# 12     0
# 620    0
# 871    1
# 649    1
# 707    1
# 414    1
# 165    1
# 362    0
# 648    0
# 146    1
# 231    0
# 674    0
# ...

# %% [markdown]
# ## Application of Supervised Learning
#
#  Notes in notebook

# %% [markdown]
# ## Data Preprocessing For Supervised Learning

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %%
# Define the Independent and Depended variable 

x= iris[['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y= iris['Species']

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
# find out  any missing values in the dataset

iris.notnull().sum()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %% [markdown]
# **Since there are no missing values in th dataset we will not do the Imputation**

# %%
# One hot encoding

#from sklern.preprocessing import OneHotEncoder
#ohe = OneHotEncoder()
#ohe = fit_transform(x)

#FOR SHORT FORM

# %% [markdown]
# **Use Pandas**
# - pd.get_dummies(df)

# %% [markdown]
# We will skip OneHotEncoding part beacause in out dataset there are no catogorical values

# %%
# Split the dataset  into train and test

from sklearn.model_selection import train_test_split

x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.20, random_state=80)

# %%
x_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 45    46            4.8           3.0            1.4           0.3
# 78    79            6.0           2.9            4.5           1.5
# 25    26            5.0           3.0            1.6           0.2
# 70    71            5.9           3.2            4.8           1.8
# 138  139            6.0           3.0            4.8           1.8
# 71    72            6.1           2.8            4.0           1.3
# 37    38            4.9           3.1            1.5           0.1
# 75    76            6.6           3.0            4.4           1.4
# 93    94            5.0           2.3            3.3           1.0
# 0      1            5.1           3.5            1.4           0.2
# 48    49            5.3           3.7            1.5           0.2
# 12    13            4.8           3.0            1.4           0.1
# 72    73            6.3           2.5            4.9           1.5
# ...

# %%
y_train
# Out:
# 45         Iris-setosa
# 78     Iris-versicolor
# 25         Iris-setosa
# 70     Iris-versicolor
# 138     Iris-virginica
# 71     Iris-versicolor
# 37         Iris-setosa
# 75     Iris-versicolor
# 93     Iris-versicolor
# 0          Iris-setosa
# 48         Iris-setosa
# 12         Iris-setosa
# 72     Iris-versicolor
# 55     Iris-versicolor
# 77     Iris-versicolor
# 57     Iris-versicolor
# 61     Iris-versicolor
# 33         Iris-setosa
# 130     Iris-virginica
# 107     Iris-virginica
# 65     Iris-versicolor
# 129     Iris-virginica
# 23         Iris-setosa
# 63     Iris-versicolor
# 113     Iris-virginica
# 96     Iris-versicolor
# 101     Iris-virginica
# 64     Iris-versicolor
# 73     Iris-versicolor
# 139     Iris-virginica
# 43         Iris-setosa
# 79     Iris-versicolor
# 127     Iris-virginica
# 52     Iris-versicolor
# 142     Iris-virginica
# 62     Iris-versicolor
# 38         Iris-setosa
# 35         Iris-setosa
# 124     Iris-virginica
# 44         Iris-setosa
# ...

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.74191039, -1.33015002, -0.096223  , -1.42657447, -1.25758547],
#        [ 0.01180052,  0.12977073, -0.33187118,  0.36870869,  0.33653696],
#        [-1.19870488, -1.0868299 , -0.096223  , -1.31074975, -1.390429  ],
#        [-0.17091727,  0.00811067,  0.37507334,  0.54244577,  0.73506756],
#        [ 1.382184  ,  0.12977073, -0.096223  ,  0.54244577,  0.73506756],
#        [-0.14807755,  0.2514308 , -0.56751935,  0.07914689,  0.07084989],
#        [-0.92462818, -1.20848996,  0.13942517, -1.36866211, -1.52327254],
#        [-0.05671865,  0.85973111, -0.096223  ,  0.31079633,  0.20369342],
#        [ 0.35439639, -1.0868299 , -1.74576021, -0.32623963, -0.32768072],
#        [-1.76969799, -0.96516983,  1.08201786, -1.42657447, -1.390429  ],
#        [-0.67339121, -0.72184971,  1.55331421, -1.36866211, -1.390429  ],
#        [-1.4956213 , -1.33015002, -0.096223  , -1.42657447, -1.52327254],
#        [-0.12523782,  0.49475092, -1.27446387,  0.60035813,  0.33653696],
# ...

# %%
x_test
# Out:
# array([[-0.65055149, -1.0868299 ,  0.61072151, -1.42657447, -1.390429  ],
#        [-0.81042956, -1.81679027,  0.37507334, -1.48448683, -1.390429  ],
#        [-0.94746791, -0.47852958,  1.08201786, -1.48448683, -1.390429  ],
#        [-0.07955837,  0.61641099, -0.33187118,  0.25288397,  0.07084989],
#        [-1.65549937, -0.60018964,  2.02461055, -1.25283739, -1.12474193],
#        [ 0.49143474, -0.23520946, -0.56751935,  0.13705925,  0.07084989],
#        [ 0.12599915,  0.12977073, -0.80316752,  0.71618285,  0.46938049],
#        [-1.35858295, -0.23520946,  1.78896238, -1.25283739, -1.25758547],
#        [-1.44994185, -0.11354939,  2.26025873, -1.54239919, -1.390429  ],
#        [-1.10734598, -1.45181009,  0.37507334, -1.31074975, -1.390429  ],
#        [ 1.08526758,  1.58969149,  0.37507334,  1.23739409,  0.73506756],
#        [ 0.10315942, -0.11354939, -0.80316752,  0.02123453, -0.06199365],
#        [-0.39931452, -1.0868299 , -2.45270473, -0.21041491, -0.32768072],
# ...

# %% [markdown]
# # Preparing & Shaping Data

# %% [markdown]
# - How to prepare the Data

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <b> Observations </b>
#
# - Here, we Pclass,name ,sex, Sibsp(no. of siblings),Parch(parent & child) , Ticket as categories.
#
# - We will drop Names which is not important in prediction of Survival rate.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Observations**
#
# - For PassengerId the description is not Applicable
#
# - There mean age is 29 and max is 80
#
# - In fares also could be Outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - Dataset has null values

# %% [markdown]
# # Data Preprocessing

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
(df['Parch'] + df['SibSp']).head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# dtype: int64

# %% [markdown]
# - let's create a variable called **Travelealone** . 0 When the person is travelling alone and 1 otherwise

# %%
df['Travelalone'] = np.where(df['Parch'] + df['SibSp'] > 0, 0 , 1)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Now that we have the variable credited we will drop all the unnecessary columns

# %%
df1 = df.drop(['PassengerId','Name','SibSp','Parch','Fare','Cabin'], axis= 1)

# %%
df1.head()
# Out:
#    Survived  Pclass     Sex   Age            Ticket Embarked
# 0         0       3    male  22.0         A/5 21171        S
# 1         1       1  female  38.0          PC 17599        C
# 2         1       3  female  26.0  STON/O2. 3101282        S
# 3         1       1  female  35.0            113803        S
# 4         0       3    male  35.0            373450        S

# %%
df1.isnull().sum()
# Out:
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# Ticket           0
# Embarked         2
# Travelalone      0
# dtype: int64

# %% [markdown]
# - Age and Embarked are the two values where values are missing

# %%
# Let's try to replace the missing values

df1['Age'].fillna(df1['Age'].median(skipna=True), inplace=True)

# %%
df1.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# Ticket         0
# Embarked       2
# Travelalone    0
# dtype: int64

# %%
df1.groupby('Embarked').count()['Survived']
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: Survived, dtype: int64

# %%
# There are Categorical values in the dataset as well. We will have to change them

df_titanic = pd.get_dummies(df1, columns=['Pclass','Embarked','Sex'],drop_first=True)

# %%
df_titanic.head()
# Out:
#    Survived   Age            Ticket  Pclass_2  Pclass_3  Embarked_Q  \
# 0         0  22.0         A/5 21171     False      True       False
# 1         1  38.0          PC 17599     False     False       False
# 2         1  26.0  STON/O2. 3101282     False      True       False
# 3         1  35.0            113803     False     False       False
# 4         0  35.0            373450     False      True       False
#
#    Embarked_S  Sex_male
# 0        True      True
# 1       False     False
# 2        True     False
# 3        True     False
# 4        True      True

# %%
df1['Age']
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5      28.00
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17     28.00
# 18     31.00
# 19     28.00
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26     28.00
# 27     19.00
# 28     28.00
# 29     28.00
# 30     40.00
# 31     28.00
# 32     28.00
# 33     66.00
# 34     28.00
# 35     42.00
# 36     28.00
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42     28.00
# 43      3.00
# 44     19.00
# 45     28.00
# 46     28.00
# 47     28.00
# 48     28.00
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55     28.00
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64     28.00
# 65     28.00
# ...

# %% [markdown]
# # Prepare Features and Target Variables
#
# what we learn
#
# - importing the packages
#
# - importing the dataset
#
# - Feature Engg (Adding Removing Features)
#
# - Imputation (Filling the Null Values)
#
# - Outliers Removal
#
# - Declaration of Dependent and Independent Variables
#
# - Scale the Data (Normalise the data)
#
# - Train Test Split

# %%
x = df_titanic.drop('Survived', axis=1)

# %%
y = df_titanic['Survived']

# %%
## Let us now try to normalise the dataset using min max scaler\

# %%
from sklearn.preprocessing import MinMaxScaler 

sc = MinMaxScaler()

# %%
df_titanic.head()
# Out:
#    Survived   Age            Ticket  Travelalone  Pclass_2  Pclass_3  \
# 0         0  22.0         A/5 21171            0     False      True
# 1         1  38.0          PC 17599            0     False     False
# 2         1  26.0  STON/O2. 3101282            1     False      True
# 3         1  35.0            113803            0     False     False
# 4         0  35.0            373450            1     False      True
#
#    Embarked_Q  Embarked_S  Sex_male
# 0       False        True      True
# 1       False       False     False
# 2       False        True     False
# 3       False        True     False
# 4       False        True      True

# %%
df_titanic[['Age','Fare']] = sc.fit_transform(df_titanic[['Age','Fare']]) ## here is something went wrong

## KeyError: "['Name'] not in index"
## KeyError: "['Fare'] not in index"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df_titanic[['Age','Fare']] = sc.fit_transform(df_titanic[['Age','Fare']]) ## here is something went wrong
#       3 ## KeyError: "['Name'] not in index"
#       4 ## KeyError: "['Fare'] not in index"
#
# File C:\Python 3.12.0\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Python 3.12.0\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
