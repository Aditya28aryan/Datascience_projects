# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('Mall_Customers.csv')

# %%
mydata.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mydata.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
var = mydata[['Annual Income (k$)','Spending Score (1-100)']]

# %%
import scipy.cluster.hierarchy as sch
dendogram = sch.dendrogram(sch.linkage(var)) # bcoz of this mess up put value in sample_df

# %%
mydata.shape
# Out:
# (200, 5)

# %%
sample_df = mydata.sample(n=25)

# %%
sample_df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 55           56    Male   47                  43                      41
# 28           29  Female   40                  29                      31
# 23           24    Male   31                  25                      73
# 69           70  Female   32                  48                      47
# 57           58    Male   69                  44                      46
# 138         139    Male   19                  74                      10
# 180         181  Female   37                  97                      32
# 12           13  Female   58                  20                      15
# 100         101  Female   23                  62                      41
# 128         129    Male   59                  71                      11
# 90           91  Female   68                  59                      55
# 98           99    Male   48                  61                      42
# ...

# %%
#var = sample_df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
import scipy.cluster.hierarchy as sch
dendogram = sch.dendrogram(sch.linkage(var))

# %%
# Complete Hierarchial Clustering

#from sklearn.cluster import AgglomerativeClustering
#hc = AgglomerativeClustering(n_clusters= 5 , affinity='euclidean')
#cluster= hc.fit_predict(var)

# %%
from sklearn.cluster import AgglomerativeClustering

# Correct usage
hc = AgglomerativeClustering(n_clusters=5) #  affinity='euclidean'-----> ye ni ho rha
clusters=hc.fit_predict(var)

# %%
mydata['cluster']=clusters

# %%
mydata
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      cluster
# 0          4
# 1          3
# 2          4
# 3          3
# 4          4
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Annual Income (k$)'  ,y= 'Spending Score (1-100)' , hue= 'cluster' , data= mydata)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>
